# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
lajas_2022 = pd.read_excel(r'C:\Users\David.Kosciulek\OneDrive - CDP Worldwide\Documents\Data\LA-JA\2022_untested_lajas.xlsx',
                          sheet_name='Sheet1', header=0)
lajas_2022.head()
# Out:
#    Account number             Organization   Country      Public  \
# 0           21308                   AAK AB    Sweden  non public
# 1           21308                   AAK AB    Sweden  non public
# 2           38247  ALEN DEL NORTE SA DE CV    Mexico  non public
# 3             618            Altri SGPS SA  Portugal      public
# 4             618            Altri SGPS SA  Portugal      public
#
#   Response received date                 Primary activity  \
# 0    2022-08-01 15:56:54            Other food processing
# 1    2022-08-01 15:56:54            Other food processing
# 2    2022-07-25 22:35:54  Supermarkets, food & drugstores
# 3    2022-07-25 10:39:47               Pulp & paper mills
# 4    2022-07-25 10:39:47               Pulp & paper mills
#
#                Primary sector              Primary industry  \
# 0  Food & beverage processing  Food, beverage & agriculture
# 1  Food & beverage processing  Food, beverage & agriculture
# ...

# %%
lajas_2022.columns
# Out:
# Index(['Account number', 'Organization', 'Country', 'Public',
#        'Response received date', 'Primary activity', 'Primary sector',
#        'Primary industry', 'Primary questionnaire sector', 'Row', 'sc or inv',
#        'F6.10b_C1_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Country/Area',
#        'F6.10b_C2_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Name of jurisdiction or landscape area',
#        'F6.10b_C3_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Is the landscape defined by administrative boundaries of sub-national governments and does the approach have active government involvement?',
# ...

# %%
lajas_2022.rename(columns={'F6.10b_C1_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Country/Area':'F6.10b_C1',
       'F6.10b_C2_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Name of jurisdiction or landscape area':'F6.10b_C2',
       'F6.10b_C3_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Is the landscape defined by administrative boundaries of sub-national governments and does the approach have active government involvement?':'F6.10b_C3',
       'F6.10b_C4_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Brief description of landscape/ jurisdictional approach':'F6.10b_C4',
       'F6.10b_C5_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Forest risk commodities relevant to this landscape/jurisdictional approach':'F6.10b_C5',
       'F6.10b_C6_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Type of engagement':'F6.10b_C6',
       'F6.10b_C7_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Description of engagement':'F6.10b_C7',
       'F6.10b_C8_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Goals supported by engagement':'F6.10b_C8',
       'F6.10b_C9_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Company actions supporting approach':'F6.10b_C9',
       'F6.10b_C10_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Implementation partner(s)':'F6.10b_C10',
       'F6.10b_C11_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Engagement start year':'F6.10b_C11',
       'F6.10b_C12_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Engagement end year':'F6.10b_C12',
       'F6.10b_C13_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Total investment over the project period (currency)':'F6.10b_C13',
       'F6.10b_C14_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Details of your investment':'F6.10b_C14',
       'F6.10b_C15_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Type of assessment framework':'F6.10b_C15',
       'F6.10b_C16_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - Is progress monitored and publicly reported on?':'F6.10b_C16',
       'F6.10b_C17_Provide details of your engagement with landscape/jurisdictional approaches to sustainable land use during the reporting year. - State the achievements of your engagement so far, and how progress is monitored':'F6.10b_C17'},
        inplace=True)
lajas_2022
# Out:
#      Account number                  Organization                   Country  \
# 0             21308                        AAK AB                    Sweden
# 1             21308                        AAK AB                    Sweden
# 2             38247       ALEN DEL NORTE SA DE CV                    Mexico
# 3               618                 Altri SGPS SA                  Portugal
# 4               618                 Altri SGPS SA                  Portugal
# ..              ...                           ...                       ...
# 236           58295              WestRock Company  United States of America
# 237           58295              WestRock Company  United States of America
# 238           20612          Weyerhaeuser Company  United States of America
# 239           20664  Wilmar International Limited                 Singapore
# 240           20917             Yum! Brands, Inc.  United States of America
#
# ...

# %%
hq_countries = lajas_2022['Country'].value_counts(sort=True)
hq_countries
# Out:
# United States of America                                57
# Japan                                                   30
# United Kingdom of Great Britain and Northern Ireland    21
# France                                                  20
# Brazil                                                  15
# Portugal                                                11
# Germany                                                 10
# Sweden                                                   8
# Singapore                                                7
# Indonesia                                                6
# Finland                                                  6
# Canada                                                   6
# Switzerland                                              5
# Mexico                                                   5
# Belgium                                                  4
# China                                                    4
# ...

# %%
primary_activity = lajas_2022['Primary activity'].value_counts(sort=True)
primary_activity
# Out:
# Personal care & household products       25
# Other food processing                    23
# Pulp & paper mills                       17
# Paper packaging                          17
# Supermarkets, food & drugstores          16
# Specialty chemicals                      11
# Paper products                            8
# Dairy & egg products                      7
# Animal processing                         7
# Sawmills & wood materials                 6
# Chemicals wholesale & distribution        5
# Other containers & packaging              5
# Tobacco products                          5
# Agricultural products wholesale           5
# Tires                                     5
# Logging                                   5
# Chocolate confection                      4
# Palm oil farming                          4
# Pharmaceuticals                           4
# Metals supply, wholesale & trading        4
# Apparel stores                            3
# ...

# %%
commodities = lajas_2022['F6.10b_C5'].value_counts(sort=True)
commodities
# Out:
# Timber products                                                                                                                                                                                                                                                            92
# Palm oil                                                                                                                                                                                                                                                                   53
# Cattle products                                                                                                                                                                                                                                                            15
# ...

# %%
lajas_2022.head()
# Out:
#    Account number             Organization   Country      Public  \
# 0           21308                   AAK AB    Sweden  non public
# 1           21308                   AAK AB    Sweden  non public
# 2           38247  ALEN DEL NORTE SA DE CV    Mexico  non public
# 3             618            Altri SGPS SA  Portugal      public
# 4             618            Altri SGPS SA  Portugal      public
#
#   Response received date                 Primary activity  \
# 0    2022-08-01 15:56:54            Other food processing
# 1    2022-08-01 15:56:54            Other food processing
# 2    2022-07-25 22:35:54  Supermarkets, food & drugstores
# 3    2022-07-25 10:39:47               Pulp & paper mills
# 4    2022-07-25 10:39:47               Pulp & paper mills
#
#                Primary sector              Primary industry  \
# 0  Food & beverage processing  Food, beverage & agriculture
# 1  Food & beverage processing  Food, beverage & agriculture
# ...

# %%
lajas_2022.iloc[3][18]
# Out:
# 'Decreased ecosystem degradation rate; Habitat connectivity restored/improved; Landscape conservation; Landscape restoration'

# %%
laja_country = lajas_2022['F6.10b_C1'].value_counts(sort=True)
laja_country
# Out:
# Indonesia                                                                                                                                                                                     53
# Brazil                                                                                                                                                                                        37
# Japan                                                                                                                                                                                         18
# United States of America                                                                                                                                                                      17
# Malaysia                                                                                                                                                                                      14
# ...

# %%
lajas_2022.columns
# Out:
# Index(['Account number', 'Organization', 'Country', 'Public',
#        'Response received date', 'Primary activity', 'Primary sector',
#        'Primary industry', 'Primary questionnaire sector', 'Row', 'sc or inv',
#        'F6.10b_C1', 'F6.10b_C2', 'F6.10b_C3', 'F6.10b_C4', 'F6.10b_C5',
#        'F6.10b_C6', 'F6.10b_C7', 'F6.10b_C8', 'F6.10b_C9', 'F6.10b_C10',
#        'F6.10b_C11', 'F6.10b_C12', 'F6.10b_C13', 'F6.10b_C14', 'F6.10b_C15',
#        'F6.10b_C16', 'F6.10b_C17'],
#       dtype='object')

# %%
laja_investment = lajas_2022[lajas_2022['F6.10b_C13'] > 1000000.0]
laja_investment
# Out:
#      Account number              Organization  \
# 8               628        Altria Group, Inc.
# 18             1641             Beiersdorf AG
# 23             2269  British American Tobacco
# 25             2414            Burberry Group
# 29             2880                 Carrefour
# ..              ...                       ...
# 225           19829              Unilever plc
# 226           19829              Unilever plc
# 227           19829              Unilever plc
# 229           32481   UPM-Kymmene Corporation
# 230           32481   UPM-Kymmene Corporation
#
#                                                Country      Public  \
# 8                             United States of America      public
# 18                                             Germany      public
# 23   United Kingdom of Great Britain and Northern I...      public
# 25   United Kingdom of Great Britain and Northern I...      public
# 29                                              France  non public
# ...

# %%
laja_area = pd.DataFrame(lajas_2022['F6.10b_C2'].value_counts(sort=True))
# laja_area = pd.DataFrame(laja_area)
laja_area
# Out:
#                                      F6.10b_C2
# Sabah                                        6
# Siak & Pelalawan                             3
# Cerrado                                      3
# Aceh                                         2
# Aceh and Riau                                2
# ...                                        ...
# South Ketapang Landscape Initiative          1
# Bandar Penawar, Johor                        1
# 世界遺産 富士山                                     1
# Sintang, West Kalimantan                     1
# Sabah  Jurisdictional Approach               1
#
# [220 rows x 1 columns]

# %%
laja_repeat_areas = laja_area[laja_area['F6.10b_C2'] > 1]
laja_repeat_areas
# Out:
#                                                     F6.10b_C2
# Sabah                                                       6
# Siak & Pelalawan                                            3
# Cerrado                                                     3
# Aceh                                                        2
# Aceh and Riau                                               2
# Mangualde                                                   2
# Concelhos de Portugal                                       2
# West Kalimantan                                             2
# Cerrado Biome, state of Tocantins                           2
# Riau province, Sumatra                                      2
# United States                                               2
# This project covers all direct supply of cattle...          2
# Finland                                                     2
# Mato Grosso                                                 2

# %%
quaire_sector = lajas_2022['Primary questionnaire sector'].value_counts(sort=True,normalize=True)
quaire_sector
# Out:
# General                     0.373444
# Paper & forestry            0.232365
# Food, beverage & tobacco    0.224066
# Agricultural commodities    0.078838
# Chemicals                   0.053942
# Construction                0.020747
# Electric utilities          0.008299
# Oil & gas                   0.004149
# Cement                      0.004149
# Name: Primary questionnaire sector, dtype: float64

# %%
eng_year_group = lajas_2022.groupby('Primary questionnaire sector')['F6.10b_C11'].agg([min,max])
eng_year_group
# Out:
#                                  min     max
# Primary questionnaire sector
# Agricultural commodities      2009.0  2022.0
# Cement                        2020.0  2020.0
# Chemicals                     2005.0  2021.0
# Construction                  2001.0  2021.0
# Electric utilities            2007.0  2021.0
# Food, beverage & tobacco      1980.0  2022.0
# General                       1991.0  2022.0
# Oil & gas                     2020.0  2020.0
# Paper & forestry              1983.0  2022.0

# %%
where_usa_engs = lajas_2022[lajas_2022['Country']=='United States of America']['F6.10b_C1'].value_counts()
where_usa_engs
# Out:
# United States of America                                                                                                                                                                      13
# Indonesia                                                                                                                                                                                     11
# Brazil                                                                                                                                                                                         9
# Ghana                                                                                                                                                                                          4
# Malaysia                                                                                                                                                                                       4
# ...
