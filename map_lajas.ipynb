# %%
import numpy as np
import pandas as pd

# %%
lajas = pd.read_excel(r'C:\Users\David.Kosciulek\Downloads\nyu_laja_map_data (1).xlsx', 
                      sheet_name='Copy of laja_map_data', header=0)
lajas.head
# Out:
# <bound method NDFrame.head of                                        Initiative Name  Area  \
# 0                                   Renature Monchique   NaN
# 1                                 Cabeço Santo Project   NaN
# 2                                         Costa Bacelo   NaN
# 3    Tavira Project: Ecological & Restoration Techn...   NaN
# 4                                       LIFE LxAquila    NaN
# ..                                                 ...   ...
# 221  Establishment of the Watershed Coordination Fo...   NaN
# 222  KEE (Essential Ecosystem Area) Nyaru Menteng M...   NaN
# 223            DECREE No. 39,469, OF NOVEMBER 22, 2018   NaN
# 224       COMPLEMENTARY LAW No. 803, OF APRIL 25, 2009   NaN
# 225           Siak Jurisdiction Investment Outlook in    NaN
#
#                   Disclosed by  \
# 0                Altri SGPS SA
# 1                Altri SGPS SA
# 2                Altri SGPS SA
# 3                Altri SGPS SA
# 4                Altri SGPS SA
# ...

# %%
lajas_pivot = pd.pivot_table(data=lajas, index='Initiative Name', 
                             values=['Disclosed by','Partners','Relevant commodities reported',
                                    'Assessment Framework','Positive Actions','confidence',
                                    'reference_area'],
                            aggfunc=', '.join)
lajas_pivot.head
# Out:
# C:\Users\David.Kosciulek\AppData\Local\Temp\ipykernel_13768\2591543667.py:1: FutureWarning: ['Positive Actions'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   lajas_pivot = pd.pivot_table(data=lajas, index='Initiative Name',
# <bound method NDFrame.head of                                                                                  Assessment Framework  \
# Initiative Name
#  Healthy Forest Landscape_SCA                       Other, please specify: Healthy Forest Landscap...
# Aceh Peat Ecosystem Protection and Management Plan                                     None Specified
# Aceh Smallholders Hub                                                No assessment framework in place
# Aceh Tamiang PPI Compact                                           Commodities Jurisdictions Approach
# ...

# %%
lajas_pivot.to_excel(r'C:\Users\David.Kosciulek\Comp Documents\jupyter\laja_aggs\map_agg.xlsx')
